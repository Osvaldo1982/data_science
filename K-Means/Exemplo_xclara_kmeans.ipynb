# %%
#https://datatofish.com/k-means-clustering-python/
#https://datascience.stackexchange.com/questions/48693/perform-k-means-clustering-over-multiple-columns
from pandas import DataFrame
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

Data = {'x': [25,34,22,27,33,33,31,22,35,34,67,54,57,43,50,57,59,52,65,47,49,48,35,33,44,45,38,43,51,46],
        'y': [79,51,53,78,59,74,73,57,69,75,51,32,40,47,53,36,35,58,59,50,25,20,14,12,20,5,29,27,8,7]
       }
  
df = DataFrame(Data,columns=['x','y'])
  
kmeans = KMeans(n_clusters=3).fit(df)
centroids = kmeans.cluster_centers_
print(centroids)

plt.scatter(df['x'], df['y'], c= kmeans.labels_.astype(float), s=50, alpha=0.5)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)
# Out:
# [[55.1 46.1]
#  [29.6 66.8]
#  [43.2 16.7]]

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %matplotlib inline
from copy import deepcopy
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

# %%
# Importing the dataset
# !wget -q https://drive.google.com/drive/folders/1OuaHZTPjGq0k6dp7OjhYTEAaX333mmkg

# %%
#https://medium.com/@snaily16/import-data-into-google-colaboratory-fe80b82e9306

from google.colab import auth
auth.authenticate_user()
import gspread
from oauth2client.client import GoogleCredentials
gc = gspread.authorize(GoogleCredentials.get_application_default())

# %%
# Open your exisiting sheet and read some data.
wks = gc.open('xclara').sheet1

# %%
# get_all_values gives a list of rows.
rows = wks.get_all_values()
headers = rows.pop(0)
print(rows)
# Out:
# [['2.072345', '-3.241693'], ['17.93671', '15.78481'], ['1.083576', '7.319176'], ['11.12067', '14.40678'], ['23.71155', '2.557729'], ['24.16993', '32.02478'], ['21.66578', '4.892855'], ['4.693684', '12.34217'], ['19.21191', '-1.121366'], ['4.230391', '-4.441536'], ['9.12713', '23.60572'], ['0.4075031', '15.29705'], ['7.314846', '3.309312'], ['-3.438403', '-12.02527'], ['17.63935', '-3.212345'], ['4.415292', '22.81555'], ['11.94122', '8.122487'], ['0.7258532', '1.806819'], ['8.185273', '28.1326'], ['-5.773587', '1.0248'], ['18.76943', '24.16946'], ['7.752016', '-3.334991'], ['10.61132', '28.44378'], ['2.02165', '-4.687122'], ['5.145525', '11.186'], ['6.24331', '19.47716'], ['-11.70671', '8.073185'], ['7.255978', '14.63704'], ['3.392373', '1.220712'], ['24.2999', '40.42887'], ['4.094005', '6.944695'], ['11.80358', '-2.445336'], ['0.09228785', '-6.651035'], ['28.50607', '-9.091833'], ['23.40831', '7.931438'], ['10.56305', '12.54468'], ['20.14157', '11.11789'], ['-1.871265', '8.60885'], ['29.30237', '14.02176'], ['18.65383', '17.21672'], ['-2.972188', '6.370999'], ['10.32313', '12.11574'], ['16.90539', '-1.355044'], ['6.75371', '12.02797'], ['23.94777', '13.35047'], ['6.883513', '6.188563'], ['-1.241542', '10.08179'], ['20.50827', '-1.57887'], ['-3.75683', '1.60851'], ['17.9176', '13.09896'], ['2.002537', '-0.656524'], ['10.7768', '15.5336'], ['24.15819', '5.330366'], ['0.3268727', '7.288787'], ['21.64777', '14.00506'], ['6.871417', '21.51998'], ['15.14264', '5.111947'], ['11.54712', '4.75756'], ['0.6611676', '-10.14263'], ['-13.66531', '16.93903'], ['24.90937', '-10.82038'], ['-4.53022', '-6.173767'], ['3.163677', '8.051481'], ['1.495172', '-7.261601'], ['7.097637', '2.105751'], ['3.509483', '24.58487'], ['12.99879', '24.91248'], ['0.3593824', '6.387915'], ['14.35429', '-2.252421'], ['3.831208', '-2.000873'], ['31.40462', '26.77209'], ['-5.501097', '13.39128'], ['-1.04476', '5.955898'], ['4.409013', '9.323681'], ['2.917201', '16.53999'], ['7.265954', '10.64794'], ['10.32038', '13.36857'], ['9.35213', '10.42427'], ['6.648532', '11.07535'], ['-1.922306', '4.888493'], ['7.22604', '13.02948'], ['8.327288', '8.540999'], ['17.69046', '21.59555'], ['16.58353', '18.16115'], ['12.35425', '31.96708'], ['2.471138', '5.482761'], ['18.4925', '29.42421'], ['10.1196', '7.162078'], ['20.40245', '3.943319'], ['12.71589', '4.531656'], ['24.35859', '-4.0644'], ['21.74312', '15.90887'], ['12.27208', '-9.612116'], ['18.29681', '22.38563'], ['3.530957', '8.673297'], ['5.026042', '36.03767'], ['-0.8633009', '-7.586249'], ['26.83892', '13.13713'], ['19.11999', '7.209715'], ['-0.8841637', '27.15254'], ['-5.191529', '29.65612'], ['9.796095', '15.43598'], ['11.66314', '10.63428'], ['9.925199', '26.80364'], ['33.90998', '15.02652'], ['9.57004', '9.2481'], ['-16.2653', '13.90024'], ['15.10579', '3.350049'], ['-4.186504', '7.96441'], ['12.54816', '32.51867'], ['-7.733469', '9.634491'], ['18.91337', '15.7414'], ['-1.050022', '-4.003455'], ['-6.894765', '1.041802'], ['23.05031', '-12.76934'], ['25.96073', '11.44522'], ['7.950795', '6.811407'], ['-3.669517', '-4.329696'], ['10.52266', '23.3561'], ['26.29452', '10.51806'], ['12.42904', '23.15663'], ['0.1170239', '24.65274'], ['-1.040023', '1.629857'], ['11.16266', '9.0201'], ['13.61452', '0.8832188'], ['8.028045', '14.82966'], ['20.40253', '22.0472'], ['8.818028', '18.90424'], ['-0.3163153', '21.40601'], ['7.190193', '9.13962'], ['-0.4711474', '-8.29095'], ['16.6546', '-1.519889'], ['10.51711', '-5.018592'], ['17.96306', '14.46713'], ['-1.315535', '11.6027'], ['5.113728', '3.961434'], ['32.25842', '-2.712702'], ['-10.59094', '15.40292'], ['21.60892', '17.75002'], ['11.31144', '1.031762'], ['11.30595', '3.068958'], ['15.51137', '8.943091'], ['15.37201', '18.17922'], ['3.77755', '13.33419'], ['17.27989', '13.97798'], ['-3.349734', '26.6599'], ['15.72571', '6.373983'], ['25.50999', '15.15837'], ['16.68281', '18.95937'], ['-4.734694', '24.09568'], ['25.08795', '19.69376'], ['7.038364', '10.6667'], ['4.521214', '-6.635 ...

# %%
#https://medium.com/@vince.shields913/reading-google-sheets-into-a-pandas-dataframe-with-gspread-and-oauth2-375b932be7bf
data = pd.DataFrame(rows, columns=headers)
print(data.head())
# Out:
#          V1         V2
# 0  2.072345  -3.241693
# 1  17.93671   15.78481
# 2  1.083576   7.319176
# 3  11.12067   14.40678
# 4  23.71155   2.557729

# %%
f1 = data['V1'].values
f2 = data['V2'].values
X = np.array(list(zip(f1, f2)))

# %%
plt.scatter(f1, f2, c='black')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create data
N = 5500
x = np.random.rand(N)
y = np.random.rand(N)
colors = (0,0,0)
area = np.pi*3

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
